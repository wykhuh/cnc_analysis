# %%
import sys
from pathlib import Path

# https://stackoverflow.com/questions/49264194/import-py-file-in-another-directory-in-jupyter-notebook
module_path = Path.cwd().parent / 'scripts'
if module_path not in sys.path:
    sys.path.append(str(module_path))

# %%
import pandas as pd
import utils

# %% [markdown]
# ## create taxa list

# %%
url = 'https://api.inaturalist.org/v1/observations/taxonomy?taxon_id=47120&verifiable=true'

# %%
url ='https://api.inaturalist.org/v1/observations/taxonomy?verifiable=true&spam=false&project_id=273661&taxon_id=47605'
taxa_csv_path = '../processed_data/Taranaki_cnc_2026_Asterales.csv'

# %%
url ='https://api.inaturalist.org/v1/observations/taxonomy?verifiable=true&spam=false&project_id=273661'
taxa_csv_path = '../processed_data/Taranaki_cnc_2026.csv'

# %%
url ='https://api.inaturalist.org/v1/observations/taxonomy?verifiable=true&spam=false&project_id=260796'
taxa_csv_path = '../processed_data/San_Antonio_cnc_2026.csv'

# %%
taxonomy_data = utils.fetchData(url)
ranks = utils.getSortedRanks(taxonomy_data)
treeData = utils.buildTree(taxonomy_data, 'id', 'parent_id' )

# %%
taxonList = []
taxon = dict()

utils.flattenTree(treeData[0], taxonList, taxon)
len(taxonList)
# Out:
# 11628

# %%
df = utils.createTaxaListCsv(taxonList, ranks)
utils.log_df(df)
# Out:
# (88, 20)
#        id  kingdom        phylum     subphylum          class      order  \
# 0   47604  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 1  632885  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 2   48561  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 3   52989  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 5   60132  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
#
#        family    subfamily     tribe   subtribe    genus subgenus section  \
# 0  Asteraceae          NaN       NaN        NaN      NaN      NaN     NaN
# 1  Asteraceae  Carduoideae  Cardueae  Carduinae      NaN      NaN     NaN
# 2  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
# 3  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
# 5  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
#
#   complex          species hybrid variety subspecies  descendant_obs_count  \
# 0     NaN              NaN    NaN     NaN        NaN                   172
# 1     NaN              NaN    NaN     NaN        NaN                    13
# 2     NaN              NaN    NaN     NaN        NaN                    10
# 3     NaN  Cirsium vulgare    NaN     NaN        NaN                     5
# 5     NaN  Cirsium arvense    NaN     NaN        NaN                     4
#
#    direct_obs_count
# 0                 1
# 1                 2
# 2                 1
# 3                 5
# 5                 4

# %%
df.to_csv(taxa_csv_path, index=False)

# %% [markdown]
# ## QC counts

# %%
obs_df = pd.read_csv('../raw_data/observations-737949.csv/observations-737949.csv')
utils.log_df(obs_df)
# Out:
# (247, 32)
#           id         time_observed_at       user_name   latitude   longitude  \
# 0  352359544  2026-04-23 20:31:04 UTC          Abby L -39.067951  174.101966
# 1  352447905  2026-04-24 02:17:44 UTC  Liam Aitchison -39.081793  174.038289
# 2  352462926  2026-04-24 02:53:56 UTC     David Munro -39.083430  174.075271
# 3  352465989  2026-04-24 03:25:29 UTC          Abby L -39.070508  174.084475
# 4  352469649  2026-04-24 03:41:42 UTC          Abby L -39.069410  174.083201
#
#        species_guess        scientific_name        common_name  \
# 0    Gallant Soldier   Galinsoga parviflora    Gallant Soldier
# 1      leopard-plant    Farfugium japonicum      leopard-plant
# 2  Kirk's tree daisy   Brachyglottis kirkii  Kirk's tree daisy
# 3        Asteroideae            Asteroideae                NaN
# 4           bluemink  Ageratum houstonianum           bluemink
#
#   iconic_taxon_name  taxon_id  ... taxon_supertribe_name taxon_tribe_name  \
# 0           Plantae     48178  ...                   NaN       Millerieae
# 1           Plantae    322755  ...                   NaN      Senecioneae
# 2           Plantae    400080  ...                   NaN      Senecioneae
# 3           Plantae    632790  ...                   NaN              NaN
# 4           Plantae    120944  ...                   NaN      Eupatorieae
#
#   taxon_subtribe_name  taxon_genus_name taxon_genushybrid_name  \
# 0        Galinsoginae         Galinsoga                    NaN
# 1      Tussilagininae         Farfugium                    NaN
# 2                 NaN     Brachyglottis                    NaN
# 3                 NaN               NaN                    NaN
# 4          Ageratinae          Ageratum                    NaN
#
#       taxon_species_name  taxon_hybrid_name taxon_subspecies_name  \
# 0   Galinsoga parviflora                NaN                   NaN
# 1    Farfugium japonicum                NaN                   NaN
# 2   Brachyglottis kirkii                NaN                   NaN
# 3                    NaN                NaN                   NaN
# 4  Ageratum houstonianum                NaN                   NaN
#
#    taxon_variety_name  taxon_form_name
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
#
# [5 rows x 32 columns]

# %%
df = pd.read_csv('../processed_data/Taranaki_cnc_2026_Asterales.csv')
utils.log_df(df)
# Out:
# (88, 20)
#        id  kingdom        phylum     subphylum          class      order  \
# 0   47604  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 1  632885  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 2   48561  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 3   52989  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
# 4   60132  Plantae  Tracheophyta  Angiospermae  Magnoliopsida  Asterales
#
#        family    subfamily     tribe   subtribe    genus subgenus section  \
# 0  Asteraceae          NaN       NaN        NaN      NaN      NaN     NaN
# 1  Asteraceae  Carduoideae  Cardueae  Carduinae      NaN      NaN     NaN
# 2  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
# 3  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
# 4  Asteraceae  Carduoideae  Cardueae  Carduinae  Cirsium      NaN     NaN
#
#   complex          species hybrid variety subspecies  descendant_obs_count  \
# 0     NaN              NaN    NaN     NaN        NaN                   172
# 1     NaN              NaN    NaN     NaN        NaN                    13
# 2     NaN              NaN    NaN     NaN        NaN                    10
# 3     NaN  Cirsium vulgare    NaN     NaN        NaN                     5
# 4     NaN  Cirsium arvense    NaN     NaN        NaN                     4
#
#    direct_obs_count
# 0                 1
# 1                 2
# 2                 1
# 3                 5
# 4                 4

# %%
set(df['id']) - set(obs_df['taxon_id'])
# Out:
# set()

# %%
set(obs_df['taxon_id']) - set(df['id'])
# Out:
# set()

# %%
for id, count in obs_df.value_counts(subset=['taxon_id']).items():
    index = df[df['id'] == id].index.values[0]
    count2 = df.at[index, 'direct_obs_count']
    if count != count2:
        print(id[0], 'count:',count, 'count2:',count2)
