# %%
import requests
import pandas as pd

# %%
df = pd.read_csv('../raw_data/List of CNC 2026 Project URLs.csv')
df.head()
# Out:
#   City Name: This is used to locate your city on the CNC website map. If more than one city is included on your project, think about where you want the pin to dropped on the map, and list only that location.  \
# 0                                         Piracicaba
# 1                                               Palu
# 2                                             Cúcuta
# 3                                   Sabana de Bogotá
# 4                                             Baraya
#
#   Online Display Name of your CNC City/Area  \
# 0                                Piracicaba
# 1                 Palu and Surrounding Area
# 2                                    Cúcuta
# 3                          Sabana de Bogotá
# 4                                    Baraya
#
#   Country/Region Name: Please choose your country/region from the list below. If your project takes place in multiple countries, please select the country with the largest land area.  \
# ...

# %%
for row in df['Project Link']:
    if type(row) == str:
        parts = row.strip().split('/')
        if len(parts) > 1:
            print(parts[4])
# Out:
# desafio-da-natureza-urbana-2026-piracicaba-sao-paulo-vizinhos-silvestres
# city-nature-challenge-2026-palu-and-surrounding-area
# city-nature-challenge-2026-cucuta
# reto-naturalista-2026-sabana-de-bogota
# reto-naturalista-urbano-baraya-2026
# reto-naturalista-2026-departamento-de-guatemala
# reto-naturalista-2026-peten
# city-nature-challenge-2026-tasmania
# c-n-c-defi-nature-urbaine-2026-tiohtia-ke-grand-montreal-greater-montreal-qc-ca
# city-nature-challenge-2026-brandon-area
# city-nature-challenge-2026-calgary-metropolitan-region
# city-nature-challenge-2026-cape-breton-regional-municipality
# city-nature-challenge-2026-charlottetown-pei
# city-nature-challenge-2026-city-of-barrie
# city-nature-challenge-2026-london-on
# city-nature-challenge-2026-metro-edmonton-area
# city-nature-challenge-2026-metro-vancouver-regional-district-mvrd
# city-nature-challenge-2026-municipality-of-chatham-kent
# city-nature-challenge-2026-ottawa
# city-nature-challenge-2026-red-deer-area
# ...
